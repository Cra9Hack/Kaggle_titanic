# %%
svc_params = {'C': np.arange(30,200,10), 
              'gamma': np.arange(0.0005,0.003,0.0005),
              'kernel': ['linear', 'poly', 'rbf', 'sigmoid'] 
             } 


svc_f1_opt = GridSearchCV(estimator = SVC(), param_grid = svc_params, cv=5 , scoring = 'f1')

svc_roc_opt = GridSearchCV(estimator = SVC(), param_grid = svc_params, cv=5 , scoring = 'roc_auc')

#svc_prec_opt = GridSearchCV(estimator = SVC(), param_grid = svc_params, cv=5 , scoring = 'precision')

svc_acc_opt = GridSearchCV(estimator = SVC(), param_grid = svc_params, cv=5 , scoring = 'accuracy')


#svc_f1w_opt = GridSearchCV(estimator = SVC(), param_grid = svc_params, cv=5 , scoring = 'f1_weighted')

models_svc = [svc_f1_opt, svc_roc_opt, svc_acc_opt ]
best_models_svc = []
for model in models_svc:
    model.fit(X_train,y_train)
    best_models_svc.append(model.best_estimator_)
    y_pred_svc = model.predict(X_test)
    acc = accuracy_score(y_test,y_pred_svc)
    print(acc)
for model in best_models_svc:
    predictions = model.predict(X_test)
    cm = confusion_matrix(y_test, predictions, labels=model.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                   display_labels=model.classes_)
    disp.plot()

    plt.show()

# %%
knn_params = { 'n_neighbors' : np.arange(2,15,1),
               'weights' : ['uniform','distance'],
               'metric' : ['minkowski','euclidean','manhattan']}


knn_f1_opt = GridSearchCV(estimator = KNeighborsClassifier(), param_grid = knn_params, cv=10 , scoring = 'f1')

knn_roc_opt = GridSearchCV(estimator = KNeighborsClassifier(), param_grid = knn_params, cv=10 , scoring = 'roc_auc')

knn_prec_opt = GridSearchCV(estimator = KNeighborsClassifier(), param_grid = knn_params, cv=10 , scoring = 'precision')


knn_acc_opt = GridSearchCV(estimator = KNeighborsClassifier(), param_grid = knn_params, cv=10 , scoring = 'accuracy')


models_knn = [knn_f1_opt, knn_roc_opt, knn_prec_opt ,knn_acc_opt]

best_models_knn = []

for model in models_knn:
    model.fit(X_train,y_train)
    best_models_knn.append(model.best_estimator_)
    y_pred_knn = model.predict(X_test)
    acc = accuracy_score(y_test,y_pred_knn)
    print(acc)
for model in best_models_knn:
    predictions = model.predict(X_test)
    cm = confusion_matrix(y_test, predictions, labels=model.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                   display_labels=model.classes_)
    disp.plot()

    plt.show()

# %%
dt_params = {'min_samples_leaf': [1, 2, 3,4,5],
             'max_depth': [ 2,3,4, 5, 6],
            'class_weight': [None,'balanced']}


dt_f1_opt = GridSearchCV(estimator = DecisionTreeClassifier(), param_grid = dt_params, cv=10 , scoring = 'f1')

dt_roc_opt = GridSearchCV(estimator = DecisionTreeClassifier(), param_grid = dt_params, cv=10 , scoring = 'roc_auc_ovo_weighted')

dt_prec_opt = GridSearchCV(estimator = DecisionTreeClassifier(), param_grid = dt_params, cv=10 , scoring = 'precision')

dt_acc_opt = GridSearchCV(estimator = DecisionTreeClassifier(), param_grid = dt_params, cv=10 , scoring = 'accuracy')

dt_f1w_opt = GridSearchCV(estimator = DecisionTreeClassifier(), param_grid = dt_params, cv=10 , scoring = 'f1_weighted')

models_dt = [dt_f1_opt, dt_roc_opt, dt_prec_opt ,dt_acc_opt, dt_f1w_opt]

best_models_dt = []

for model in models_dt:
    model.fit(X_train,y_train)
    best_models_dt.append(model.best_estimator_)
    y_pred_dt = model.predict(X_test)
    acc = accuracy_score(y_test,y_pred_dt)
    print(acc)
for model in best_models_dt:
    predictions = model.predict(X_test)
    cm = confusion_matrix(y_test, predictions, labels=model.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                   display_labels=model.classes_)
    disp.plot()

    plt.show()

# %%
logreg_params =     {
    'penalty' : ['l1', 'l2'],
    'C' : np.logspace(-4, 4, 20),
    'solver' : ['liblinear'],
    'max_iter' : [10000,12500, 15000],
    'warm_start': [True, False]
    }  


logreg_f1_opt = GridSearchCV(estimator = LogisticRegression(), param_grid = logreg_params, cv=10 , scoring = 'f1')

logreg_roc_opt = GridSearchCV(estimator = LogisticRegression(), param_grid = logreg_params, cv=10 , scoring = 'roc_auc_ovo_weighted')

#logreg_prec_opt = GridSearchCV(estimator = LogisticRegression(), param_grid = logreg_params, cv=10 , scoring = 'precision')

logreg_acc_opt = GridSearchCV(estimator = LogisticRegression(), param_grid = logreg_params, cv=10 , scoring = 'accuracy')

#logreg_f1w_opt = GridSearchCV(estimator = LogisticRegression(), param_grid = logreg_params, cv=10 , scoring = 'f1_weighted')

models_logreg = [logreg_f1_opt, logreg_roc_opt ,logreg_acc_opt]

best_models_logreg = []

for model in models_logreg:
    model.fit(X_train,y_train)
    best_models_logreg.append(model.best_estimator_)
    y_pred_logreg = model.predict(X_test)
    acc = accuracy_score(y_test,y_pred_logreg)
    print(acc)
for model in best_models_logreg:
    predictions = model.predict(X_test)
    cm = confusion_matrix(y_test, predictions, labels=model.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                   display_labels=model.classes_)
    disp.plot()

    plt.show()

# %%
rf_params={
    'max_depth': [3,5,7,9],
    'n_estimators': np.arange(50,300,50),
    'criterion': ['gini','entropy','log_loss'],
    #'max_features': np.arange(0.1,1,0.3),
    'max_samples': [0.3,0,5,0.8]}

rf_f1_opt = GridSearchCV(estimator = RandomForestClassifier(n_jobs = -1), param_grid = rf_params, cv=10 , scoring = 'f1')

rf_roc_opt = GridSearchCV(estimator = RandomForestClassifier(n_jobs = -1), param_grid = rf_params, cv=10 , scoring = 'roc_auc')

#logreg_prec_opt = GridSearchCV(estimator = LogisticRegression(), param_grid = logreg_params, cv=10 , scoring = 'precision')

rf_acc_opt = GridSearchCV(estimator = RandomForestClassifier(n_jobs = -1), param_grid = rf_params, cv=10 , scoring = 'accuracy')

#rf_f1w_opt = GridSearchCV(estimator = RandomForestClassifier(n_jobs = -1), param_grid = rf_params, cv=10 , scoring = 'f1_weighted')

models_rf = [rf_f1_opt, rf_roc_opt ,rf_acc_opt]

best_models_rf = []

for model in models_rf:
    model.fit(X_train,y_train)
    best_models_rf.append(model.best_estimator_)
    y_pred_rf = model.predict(X_test)
    acc = accuracy_score(y_test,y_pred_rf)
    print(acc)
for model in best_models_rf:
    predictions = model.predict(X_test)
    cm = confusion_matrix(y_test, predictions, labels=model.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                   display_labels=model.classes_)
    disp.plot()

    plt.show()

# %%
bc_params = {
    'max_features': np.arange(0.1,1,0.1),
    'n_estimators' :np.arange(60,300,20)}

bc_f1_opt = GridSearchCV(estimator = BaggingClassifier(n_jobs = -1, oob_score = True), param_grid = bc_params, cv=10 , scoring = 'f1')

bc_roc_opt = GridSearchCV(estimator = BaggingClassifier(n_jobs = -1, oob_score = True), param_grid = bc_params, cv=10 , scoring = 'roc_auc')

#logreg_prec_opt = GridSearchCV(estimator = LogisticRegression(), param_grid = logreg_params, cv=10 , scoring = 'precision')

bc_acc_opt = GridSearchCV(estimator = BaggingClassifier(n_jobs = -1, oob_score = True), param_grid = bc_params, cv=10 , scoring = 'accuracy')

bc_f1w_opt = GridSearchCV(estimator = BaggingClassifier(n_jobs = -1, oob_score = True), param_grid = bc_params, cv=10 , scoring = 'f1_weighted')

models_bc = [bc_f1_opt, bc_roc_opt ,bc_acc_opt, bc_f1w_opt]

best_models_bc = []

for model in models_bc:
    model.fit(X_train,y_train)
    best_models_bc.append(model.best_estimator_)
    y_pred_bc = model.predict(X_test)
    acc = accuracy_score(y_test,y_pred_bc)
    print(acc)
for model in best_models_bc:
    predictions = model.predict(X_test)
    cm = confusion_matrix(y_test, predictions, labels=model.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                   display_labels=model.classes_)
    disp.plot()

    plt.show()

# %%
ag_params = {
    'n_estimators' :np.arange(60,200,20),
    'learning_rate': [0.05, 0.1, 0.15,0.5,1] } 

ag_f1_opt = GridSearchCV(estimator = AdaBoostClassifier(), param_grid = ag_params, cv=10 , scoring = 'f1')

ag_roc_opt = GridSearchCV(estimator = AdaBoostClassifier(), param_grid = ag_params, cv=10 , scoring = 'roc_auc')

#logreg_prec_opt = GridSearchCV(estimator = LogisticRegression(), param_grid = logreg_params, cv=10 , scoring = 'precision')

ag_acc_opt = GridSearchCV(estimator = AdaBoostClassifier(), param_grid = ag_params, cv=10 , scoring = 'accuracy')

ag_f1w_opt = GridSearchCV(estimator = AdaBoostClassifier(), param_grid = ag_params, cv=10 , scoring = 'f1_weighted')

models_ag = [ag_f1_opt, ag_roc_opt ,ag_acc_opt, ag_f1w_opt]

best_models_ag = []

for model in models_ag:
    model.fit(X_train,y_train)
    best_models_ag.append(model.best_estimator_)
    y_pred_ag = model.predict(X_test)
    acc = accuracy_score(y_test,y_pred_ag)
    print(acc)
for model in best_models_ag:
    predictions = model.predict(X_test)
    cm = confusion_matrix(y_test, predictions, labels=model.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                   display_labels=model.classes_)
    disp.plot()

    plt.show()

# %%
sgbt = GradientBoostingClassifier()
sgbt_params = { 
    'max_depth': [2,3,4],
    'n_estimators' :np.arange(60,200,20),
    'subsample': np.arange(0.5,0.8,0.1) ,
    'max_features': np.arange(0.1,0.4,0.1)} 

sgbt_f1_opt = GridSearchCV(estimator = GradientBoostingClassifier(),n_jobs = -1, param_grid = sgbt_params, cv=10 , scoring = 'f1')

sgbt_roc_opt = GridSearchCV(estimator = GradientBoostingClassifier(),n_jobs = -1, param_grid = sgbt_params, cv=10 , scoring = 'roc_auc')

#logreg_prec_opt = GridSearchCV(estimator = LogisticRegression(), param_grid = logreg_params, cv=10 , scoring = 'precision')

sgbt_acc_opt = GridSearchCV(estimator = GradientBoostingClassifier(),n_jobs = -1, param_grid = sgbt_params, cv=10 , scoring = 'accuracy')

sgbt_f1w_opt = GridSearchCV(estimator = GradientBoostingClassifier(),n_jobs = -1, param_grid = sgbt_params, cv=10 , scoring = 'f1_weighted')

models_sgbt = [sgbt_f1_opt, sgbt_roc_opt ,sgbt_acc_opt, sgbt_f1w_opt]

best_models_sgbt = []

for model in models_sgbt:
    model.fit(X_train,y_train)
    best_models_sgbt.append(model.best_estimator_)
    y_pred_sgbt = model.predict(X_test)
    acc = accuracy_score(y_test,y_pred_sgbt)
    print(acc)
for model in best_models_sgbt:
    predictions = model.predict(X_test)
    cm = confusion_matrix(y_test, predictions, labels=model.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                   display_labels=model.classes_)
    disp.plot()

    plt.show()
